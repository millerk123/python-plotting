# %% [markdown]
# # Landau Damping Visualization Script
# #
# #
# #
# # F. S. Tsung
# #
# # 2017 HED Summer School

# %%
# Langmuir Decay Instability
# In this example we excite a nonlinear plasma wave @ mode 4.  It decays into a backward going EPW @ mode 4 and
# also a IAW (at mode 8).  The python scripts looks at the time history of the EPW's and the Ion Density History.
#
#  Input Deck is at the end of this notebook as well
#

# %%
#
# The usual prefix, loading the necessary libraries
#
import h5py
import numpy as np
import matplotlib.pyplot as plt
from analysis import *
from h5_utilities import *
# %matplotlib notebook

# %%
# First, look at EPW -->  The horizontal axes is the x-position, and the vertical axes is time.  
# In the beginning of the simulation, the plasma wave is going strictly from left to right

# %%
# read the history file, plot it vs time and space
test4=read_hdf('/Users/franktsung/Documents/work/summer_school_2017/examples/ldi/ldi-r10-epw.h5')
test4.data=test4.data
plt.figure()
plotme(test4)
# plt.figure()
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# here we fourier analyze the data in space
#
# k_data=np.fft.fft(test.data,axis=1)
k_data=np.fft.fft(test4.data,axis=1)
# k_data_2=np.fft.fft(k_data,axis=0)
# autocorrelate_2d(k_data,axes=0)
test4.data=np.log(np.abs(k_data)+0.00000000001)
#test4.axes[1].axis_max=2.0*3.1415926/0.4
test4.axes[0].axis_max=2.0*3.1415926
# test.data=k_data
# autocorrelate_2d(test.data,axes=0)

# test_fft=np.fft.fft(test.data,axis=0)
# test_fft_2=np.fft.fft(test_fft,axis=0)
#test.data=np.log10(np.real(test_fft)+1e-10)

# %%
# create new figure, showing data as a function of k and time.
plt.figure()
plotme(test4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot mode history for a couple of modes
plt.figure()
plt.semilogy(test4.data[:,4])
plt.semilogy(test4.data[:,12])
plt.semilogy(test4.data[:,16])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#
# Now Look at the Ion Density  -->  The ion wave is moving backwards (like the pump)
# at the sound speed, which is much less than the velocity of the EPW.
#
#
test2=read_hdf('/Users/franktsung/Documents/work/summer_school_2017/examples/ldi/ldi-r10-ni.h5')
test2.data=test2.data
plt.figure()
plotme(test2)
plt.show()
# plt.figure()
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# here we fourier analyze the data in space
#
# k_data=np.fft.fft(test.data,axis=1)
k_data=np.fft.fft(test2.data,axis=1)
# k_data_2=np.fft.fft(k_data,axis=0)
# autocorrelate_2d(k_data,axes=0)
test2.data=np.log(np.abs(k_data)+0.00000000001)
#test4.axes[1].axis_max=2.0*3.1415926/0.4
test2.axes[0].axis_max=2.0*3.1415926
# test.data=k_data
# autocorrelate_2d(test.data,axes=0)

# test_fft=np.fft.fft(test.data,axis=0)
# test_fft_2=np.fft.fft(test_fft,axis=0)
#test.data=np.log10(np.real(test_fft)+1e-10)

# create new figure, showing data as a function of k and time.
plt.figure()
plotme(test2)
# Out:
# <img src="data:image/png;base64,..." width="640">
