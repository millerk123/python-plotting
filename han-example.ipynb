# %%
import sys
sys.path.append("/Users/franktsung/Documents/work/codes/pyVisOS") # go to parent dir

import osh5io
import osh5vis
import osh5visipy

# %matplotlib notebook
# Out:
# Importing osh5visipy. Please use `%matplotlib notebook' in your jupyter/ipython notebook

# %% [markdown]
# osh5visipy.slicer_w('/Volumes/Lacie-5TB/runs/compass-2018/run1/MS/FLD/e1')

# %%
osh5visipy.slicer_w('/Volumes/Lacie-5TB/runs/compass-2018/run1/MS/FLD/e3')
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# /Users/franktsung/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
osh5visipy.slicer_w('/Volumes/Lacie-5TB/runs/compass-2018/run1/MS/DENSITY/electrons/charge')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
osh5visipy.slicer_w('/Volumes/Lacie-5TB/runs/srs-trident-1d/2e16/MS/PHA/p1x1/species_1')
# Out:
# <img src="data:image/png;base64,..." width="640">
